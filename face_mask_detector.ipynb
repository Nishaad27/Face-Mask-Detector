# %%
import os

# %%
path_of_dir = "C:/Users/nisha/OneDrive/Desktop/FACE MASK DETECTION/archive (15)/data"

# %%
print(os.listdir(path_of_dir))
# Out:
# ['without_mask', 'with_mask']

# %%
import cv2
import matplotlib.image as mping
from matplotlib import pyplot as plt
# Out:
# C:\Users\nisha\AppData\Roaming\Python\Python311\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
categories = ['with_mask','without_mask']

# %%
data = []
for category in categories:
    label = categories.index(category)
    path = os.path.join(path_of_dir,category)
    for file in os.listdir(path):
        img = cv2.imread(os.path.join(path,file))
        img = cv2.resize(img,(224,224))
        data.append([img,label])

# %%
plt.imshow(data[0][0])

# %%
import random

# %%
random.shuffle(data)

# %%
X = []
Y = []

for features,labels in data:
    X.append(features)
    Y.append(labels)

# %%
import numpy as np

X = np.array(X)
Y = np.array(Y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,stratify = Y,random_state = 2)

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
vgg16 = VGG16()

# %%
model = Sequential()
for layer in vgg16.layers:
    layer.trainable = False

for layer in vgg16.layers[:-1]:
    model.add(layer)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ...

# %%
model.add(Dense(1,activation = 'sigmoid'))

# %% [markdown]
# model.summary()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ...

# %%
model.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
import tensorflow as tf

# %%
class myCallBack(tf.keras.callbacks.Callback ):
    def on_epoch_end(self,epoch,logs=None):
        if logs.get('accuracy') > 0.99:
            print("Training accuracy has reached  99%")
            self.model.stop_training = True

# %%
model.fit(X_train,Y_train,validation_data = (X_test,Y_test),epochs = 10,callbacks = [myCallBack()])
# Out:
# Epoch 1/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 699s 4s/step - accuracy: 0.9372 - loss: 0.1501 - val_accuracy: 0.9914 - val_loss: 0.0265
# Epoch 2/10
# Training accuracy has reached  99%━━━━━━━ 0s 3s/step - accuracy: 0.9933 - loss: 0.0208
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 623s 3s/step - accuracy: 0.9933 - loss: 0.0208 - val_accuracy: 0.9881 - val_loss: 0.0289

# %%
model.save('face_mask_detector.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# model.save('face_mask_detector.h5')

# %%
import pandas as pd

# %%
haar = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

# %%
def detect_face_mask(img):
    y_pred = model.predict(img.reshape(1,224,224,3))
    if y_pred[0][0] >=0.5:
        return 1
    else:
        return 0

# %%
def detect_face(img):
    coods = haar.detectMultiScale(img)
    return coods

# %%
def draw_label(img,text,pos,bg_color):

    text_size = cv2.getTextSize(text,cv2.FONT_HERSHEY_SIMPLEX,1,cv2.FILLED)
    end_x  = pos[0] + text_size[0][0]+2
    end_y  = pos[1] + text_size[0][1] -2
    cv2.rectangle(img,pos,(end_x,end_y),bg_color,cv2.FILLED)
    cv2.putText(img,text,pos,cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1,cv2.LINE_AA)

# %%
def detect_face_mask(img):
    y_pred = model.predict(img.reshape(1,224,224,3))
    if y_pred[0][0] >=0.5:
        return 1
    else:
        return 0

# %%
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()

    img = cv2.resize(frame,(224,224))
    coods = detect_face(cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY))
    for x,y,w,h in coods:
        cv2.rectangle(frame,(x,y),(x+h,y+w),(255,0,0),thickness = 3)
        y_pred = detect_face_mask(img)
        if y_pred == 0:
            cv2.putText(frame,"Mask",(x,y-3),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),1,cv2.LINE_AA)
        else:
            cv2.putText(frame,"No Mask",(x,y-3),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),1,cv2.LINE_AA)
    cv2.imshow("webcam",frame)
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# ...

# %%
cap = cv2.VideoCapture(0)

while True:
    ret,frame = cap.read()
    
    img = cv2.resize(frame,(224,224))
    coods = detect_face(cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY))
    for x,y,w,h in coods:
        
            cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),thickness = 3)
    
    y_pred = detect_face_mask(img)
    if y_pred == 0:
        draw_label(frame,"Mask",(50,50),(0,255,0))
    else:
        draw_label(frame,"No Mask",(50,50),(0,0,255))
    cv2.imshow("webcam",frame)
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# ...

# %%
print(tf.__version__)
# Out:
# 2.16.1
